# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
flower=load_iris()
import matplotlib.pyplot as plt

# %%
dir(flower)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
df=pd.DataFrame(flower.data)
df.head()
# Out:
#      0    1    2    3
# 0  5.1  3.5  1.4  0.2
# 1  4.9  3.0  1.4  0.2
# 2  4.7  3.2  1.3  0.2
# 3  4.6  3.1  1.5  0.2
# 4  5.0  3.6  1.4  0.2

# %%
df['target']=flower.target
df
# Out:
#        0    1    2    3  target
# 0    5.1  3.5  1.4  0.2       0
# 1    4.9  3.0  1.4  0.2       0
# 2    4.7  3.2  1.3  0.2       0
# 3    4.6  3.1  1.5  0.2       0
# 4    5.0  3.6  1.4  0.2       0
# ..   ...  ...  ...  ...     ...
# 145  6.7  3.0  5.2  2.3       2
# 146  6.3  2.5  5.0  1.9       2
# 147  6.5  3.0  5.2  2.0       2
# 148  6.2  3.4  5.4  2.3       2
# 149  5.9  3.0  5.1  1.8       2
#
# [150 rows x 5 columns]

# %%
x=df.drop(['target'],axis='columns')
y=df.target

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8)

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(n_estimators=43) #n_estimators=10

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=43)

# %%
model.predict(x_test)
# Out:
# array([2, 1, 2, 0, 0, 2, 1, 0, 1, 1, 2, 1, 2, 0, 2, 0, 1, 2, 2, 1, 2, 1,
#        0, 2, 2, 1, 2, 1, 1, 0])

# %%
model.score(x_test,y_test)*100
# Out:
# 96.66666666666667

# %%
# Out:
# 96.66666666666667
